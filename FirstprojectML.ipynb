# %% [markdown]
# <a href="https://colab.research.google.com/github/joxe22/Demo_text/blob/main/FirstprojectML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Statistician project for Machine Learning

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f57f0f2d-16c9-42b8-b957-4b4ebb699931" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f57f0f2d-16c9-42b8-b957-4b4ebb699931">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
import pandas as pd
Datos_Proyectos_de_Machine_Learning = pd.read_csv(io.BytesIO(uploaded['Datos-Proyectos-de-Machine-Learning.csv']))

# %%
Datos_Proyectos_de_Machine_Learning
# Out:
#    Estadisticas de consumidores de tabaco (periodo mayo-agosto de 2014)  \
# 0                                                 NaN
# 1                                                 ES:
# 2                                             FUMADOR
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                           EXFUMADOR
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                       NUNCA HA FU.
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
#
#             Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4          Unnamed: 5  \
# ...

# %%
Datos_Proyectos_de_Machine_Learning["Unnamed: 5"]
# Out:
# 0                    NaN
# 1     Zona de Residencia
# 2                  RURAL
# 3                 URBANA
# 4                    NaN
# 5                    NaN
# 6                  RURAL
# 7                 URBANA
# 8                    NaN
# 9                    NaN
# 10                 RURAL
# 11                URBANA
# 12                   NaN
# 13                   NaN
# Name: Unnamed: 5, dtype: object

# %%
Datos_Proyectos_de_Machine_Learning.Info()
